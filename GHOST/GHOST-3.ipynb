# %% [markdown]
# # GHOST - Quantum Computing 3

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Operator

qc = QuantumCircuit(2)
qc.x(0)

# Wizualizacja
print(qc.draw())
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
